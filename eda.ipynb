# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df =  pd.read_csv('./data/data.csv')
df.head()
# Out:
# C:\Users\vharm\AppData\Local\Temp\ipykernel_19244\2746965036.py:1: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv('./data/data.csv')
#                      Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0             Alona Vladi   F   SBD       Raw  33.0    24-34          24-39
# 1      Galina Solovyanova   F   SBD       Raw  43.0    40-44          40-49
# 2          Daniil Voronin   M   SBD       Raw  15.5    16-17          14-18
# 3          Aleksey Krasov   M   SBD       Raw  35.0    35-39          24-39
# 4  Margarita Pleschenkova   M   SBD       Raw  26.5    24-34          24-39
#
#   Division  BodyweightKg WeightClassKg  ...  Tested  Country  State  \
# 0        O         58.30            60  ...     Yes   Russia    NaN
# 1       M1         73.10            75  ...     Yes   Russia    NaN
# 2        T         67.40            75  ...     Yes   Russia    NaN
# 3        O         66.65            75  ...     Yes   Russia    NaN
# 4        O         72.45            75  ...     Yes   Russia    NaN
#
#    Federation  ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# 0         GFP               NaN  2019-05-11       Russia        NaN   Bryansk
# 1         GFP               NaN  2019-05-11       Russia        NaN   Bryansk
# 2         GFP               NaN  2019-05-11       Russia        NaN   Bryansk
# 3         GFP               NaN  2019-05-11       Russia        NaN   Bryansk
# 4         GFP               NaN  2019-05-11       Russia        NaN   Bryansk
#
#           MeetName
# 0  Open Tournament
# 1  Open Tournament
# 2  Open Tournament
# 3  Open Tournament
# 4  Open Tournament
#
# [5 rows x 41 columns]

# %%
df['Country'].value_counts().plot(kind='bar', title='Country Distribution')
# Out:
# <Axes: title={'center': 'Country Distribution'}, xlabel='Country'>

# %%
df_armenia = df[df['Country'] == 'Armenia']
df_armenia
# Out:
#                          Name Sex Event   Equipment   Age AgeClass  \
# 9098         Kevork Tutunjian   M   SBD       Wraps  35.0    35-39
# 9104          Gegham Hakobyan   M   SBD       Wraps  39.0    35-39
# 9105     Shavarsh Khachatrian   M   SBD       Wraps  33.0    24-34
# 9159          Artyom Khugoyan   M    BD         Raw  31.0    24-34
# 9166         Lusine Mkrtchyan   F    BD         Raw  43.0    40-44
# ...                       ...  ..   ...         ...   ...      ...
# 2865732         Gagik Adamyan   M   SBD  Single-ply  16.5    16-17
# 2872096        Sevak Manukyan   M     B  Single-ply  23.5    24-34
# 2877126      Yuri Karoglanyan   M     B         Raw  18.5    18-19
# 2877564       Sergey Asaturov   M   SBD         Raw  32.5    24-34
# 2877719      Yuri Karoglanyan   M   SBD         Raw  17.5    18-19
#
#         BirthYearClass              Division  BodyweightKg WeightClassKg  ...  \
# 9098             24-39  Pro Submasters 33-39         97.45           100  ...
# 9104             40-49  Pro Submasters 33-39        119.35           125  ...
# 9105             24-39  Pro Submasters 33-39        128.75           140  ...
# 9159             24-39              Pro Open        109.95           110  ...
# 9166             40-49     Pro Masters 40-44         64.25          67.5  ...
# ...                ...                   ...           ...           ...  ...
# 2865732          14-18           Sub-Juniors         59.80            60  ...
# 2872096          24-39                  Open         55.46            56  ...
# 2877126          19-23               Juniors        113.10           120  ...
# 2877564          24-39                  Open         73.64            74  ...
# 2877719          14-18           Sub-Juniors        103.18           105  ...
#
#          Tested  Country  State  Federation  ParentFederation        Date  \
# 9098        NaN  Armenia    NaN         WPA               NaN  2021-04-14
# 9104        NaN  Armenia    NaN         WPA               NaN  2021-04-14
# 9105        NaN  Armenia    NaN         WPA               NaN  2021-04-14
# 9159        NaN  Armenia    NaN         WPA               NaN  2021-04-14
# 9166        NaN  Armenia    NaN         WPA               NaN  2021-04-14
# ...         ...      ...    ...         ...               ...         ...
# 2865732     Yes  Armenia    NaN         IPF               IPF  2006-09-05
# 2872096     Yes  Armenia    NaN         IPF               IPF  2007-05-29
# 2877126     Yes  Armenia    NaN         IPF               IPF  2018-05-14
# 2877564     Yes  Armenia    NaN         IPF               IPF  2017-06-14
# 2877719     Yes  Armenia    NaN         IPF               IPF  2017-06-14
#
#          MeetCountry  MeetState   MeetTown  \
# 9098          Poland        NaN  Pabianice
# 9104          Poland        NaN  Pabianice
# 9105          Poland        NaN  Pabianice
# 9159          Poland        NaN  Pabianice
# 9166          Poland        NaN  Pabianice
# ...              ...        ...        ...
# 2865732     Bulgaria        NaN      Sofia
# 2872096      Denmark        NaN    Thisted
# 2877126      Finland        NaN     Vantaa
# 2877564      Belarus        NaN      Minsk
# 2877719      Belarus        NaN      Minsk
#
#                                                   MeetName
# 9098                                   World Championships
# 9104                                   World Championships
# 9105                                   World Championships
# 9159                                   World Championships
# 9166                                   World Championships
# ...                                                    ...
# 2865732  World Sub-Juniors & Juniors Powerlifting Champ...
# 2872096                    World Bench Press Championships
# 2877126            World Classic Bench Press Championships
# 2877564           World Classic Powerlifting Championships
# 2877719           World Classic Powerlifting Championships
#
# [642 rows x 41 columns]
